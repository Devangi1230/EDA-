# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\admin\Downloads\Telegram Desktop\winequality-white.csv")

# %%
df
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# ...                                                 ...
# 4893  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...
# 4894  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...
# 4895  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....
# 4896  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...
# 4897  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...
#
# [4898 rows x 1 columns]

# %%
df = pd.read_csv(r"C:\Users\admin\Downloads\Telegram Desktop\winequality-white.csv", delimiter=';', quotechar='"')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['fixed acidity'].unique()
# Out:
# array([ 7.  ,  6.3 ,  8.1 ,  7.2 ,  6.2 ,  8.6 ,  7.9 ,  6.6 ,  8.3 ,
#         7.4 ,  6.5 ,  6.4 ,  6.8 ,  7.6 ,  6.9 ,  8.5 ,  5.8 ,  7.3 ,
#         6.7 ,  6.  ,  7.1 ,  6.1 ,  7.5 ,  9.8 ,  5.5 ,  5.9 ,  7.8 ,
#         5.7 ,  8.2 ,  5.6 ,  5.2 ,  8.4 , 10.2 ,  7.7 ,  5.3 ,  5.4 ,
#         9.1 ,  5.  ,  8.  , 10.  ,  5.1 ,  9.2 ,  9.  ,  8.8 ,  8.7 ,
#         4.8 , 10.3 ,  9.4 ,  9.6 ,  9.3 ,  8.9 ,  9.7 , 10.7 , 14.2 ,
#         9.9 ,  9.5 , 11.8 ,  4.6 ,  6.15,  4.5 ,  7.15,  6.45,  4.2 ,
#         4.9 ,  4.7 ,  3.8 ,  4.4 ,  3.9 ])

# %%
df['volatile acidity'].unique()
# Out:
# array([0.27 , 0.3  , 0.28 , 0.23 , 0.32 , 0.22 , 0.18 , 0.16 , 0.42 ,
#        0.17 , 0.48 , 0.66 , 0.34 , 0.31 , 0.26 , 0.67 , 0.25 , 0.24 ,
#        0.14 , 0.12 , 0.39 , 0.33 , 0.45 , 0.46 , 0.19 , 0.2  , 0.21 ,
#        0.38 , 0.47 , 0.35 , 0.54 , 0.43 , 0.44 , 0.265, 0.36 , 0.305,
#        0.13 , 0.41 , 0.485, 0.425, 0.37 , 0.255, 0.595, 0.29 , 0.53 ,
#        0.15 , 0.57 , 0.4  , 0.245, 0.685, 0.495, 0.64 , 0.52 , 0.115,
#        0.58 , 0.585, 0.59 , 0.6  , 0.55 , 0.125, 0.1  , 0.145, 0.335,
#        0.365, 0.905, 0.49 , 0.155, 0.51 , 0.62 , 0.345, 0.475, 0.56 ,
#        0.235, 0.105, 0.5  , 0.11 , 0.225, 0.395, 0.655, 0.205, 0.415,
#        0.705, 0.08 , 0.68 , 0.275, 0.61 , 0.135, 0.165, 0.85 , 0.185,
#        0.325, 0.445, 0.545, 0.91 , 0.71 , 1.005, 0.385, 0.76 , 0.93 ,
#        0.295, 0.695, 0.815, 0.285, 0.175, 0.615, 0.315, 0.965, 0.375,
#        0.74 , 0.78 , 0.215, 0.435, 0.75 , 0.085, 0.73 , 0.65 , 0.455,
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df["quality"].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %% [markdown]
# # Explore analysis

# %%
numeric_col= [col for col in df.columns if df[col].dtype!='0']
print("We have {} Numeric Columns :{}".format (len(numeric_col),numeric_col))
# Out:
# We have 12 Numeric Columns :['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
for cols in numeric_col:
    print(df[cols].value_counts(normalize=True)*100)
    print('______________________________________________________')
# Out:
# fixed acidity
# 6.8     6.288281
# 6.6     5.920784
# 6.4     5.716619
# 6.9     4.920376
# 6.7     4.818293
#           ...
# 4.5     0.020416
# 4.6     0.020416
# 11.8    0.020416
# 14.2    0.020416
# 3.9     0.020416
# Name: proportion, Length: 68, dtype: float64
# ______________________________________________________
# volatile acidity
# 0.280    5.369539
# 0.240    5.165374
# 0.260    4.899959
# 0.250    4.716211
# 0.220    4.675378
#            ...
# 0.545    0.020416
# 0.135    0.020416
# 0.905    0.020416
# 0.685    0.020416
# 0.355    0.020416
# Name: proportion, Length: 125, dtype: float64
# ______________________________________________________
# citric acid
# 0.30    6.267864
# 0.28    5.757452
# 0.32    5.247040
# 0.34    4.593712
# 0.29    4.552879
#           ...
# 1.66    0.020416
# 1.23    0.020416
# 0.86    0.020416
# 0.11    0.020416
# 0.99    0.020416
# Name: proportion, Length: 87, dtype: float64
# ______________________________________________________
# ...

# %% [markdown]
# # Data Visualisation

# %%
plt.figure(figsize=(15,16))
plt.suptitle("Univariate Analysis of Numeric Columns",fontsize=20, fontweight='bold',y=1.)

for i in range(0,len(numeric_col)):
    plt.subplot(4,3,i+1)
    sns.kdeplot(x=df[numeric_col[i]],shade=True,color='r')
    plt.xlabel(numeric_col[i])
    plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5332\361359792.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df[numeric_col[i]],shade=True,color='r')
# C:\Users\admin\AppData\Local\Temp\ipykernel_5332\361359792.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df[numeric_col[i]],shade=True,color='r')
# C:\Users\admin\AppData\Local\Temp\ipykernel_5332\361359792.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df[numeric_col[i]],shade=True,color='r')
# C:\Users\admin\AppData\Local\Temp\ipykernel_5332\361359792.py:6: FutureWarning:
#
# ...

# %%
plt.figure(figsize=(15,16))
plt.suptitle("Univariate Analysis of Numeric Column outlier",fontsize=20, fontweight='bold',y=1.)

for i in range(0,len(numeric_col)):
    plt.subplot(4,3,i+1)
    sns.boxplot(y=df[numeric_col[i]],color='skyblue')
    plt.xlabel(numeric_col[i])
    plt.tight_layout()
plt.show()

# %%
df["quality"].value_counts().sort_index().plot(kind="bar",figsize=(10,5))
plt.title("Distribution of Wine Quality Ratings", fontsize=16, fontweight='bold')
plt.xlabel("Quality Score")
plt.ylabel("Number of Wines")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=0)
plt.show()

# %%
corr_matrix = df.corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr_matrix, cmap='coolwarm',square=True,linewidths=0.5)
plt.title("Correalation of Wine Features Through heatmap", fontsize=16, fontweight='bold')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
plt.figure(figsize=(12,10))
sns.lineplot(x='alcohol',y='quality',data=df)
plt.suptitle("Alcohol Vs Quality")
plt.xlabel='Alcohol'
plt.ylabel='Quality'
plt.tight_layout()
plt.show()

# %%
df[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']].corr()['quality']
# Out:
# fixed acidity          -0.113663
# volatile acidity       -0.194723
# citric acid            -0.009209
# residual sugar         -0.097577
# chlorides              -0.209934
# free sulfur dioxide     0.008158
# total sulfur dioxide   -0.174737
# density                -0.307123
# pH                      0.099427
# sulphates               0.053678
# alcohol                 0.435575
# quality                 1.000000
# Name: quality, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='density',y='alcohol',data=df)
plt.suptitle("density Vs alcohol")
plt.xlabel='density'
plt.ylabel='alcohol'
plt.tight_layout()
plt.show()

# %%
features = ['alcohol', 'volatile acidity', 'density']

# %%
grouped = df.groupby('quality')[features].mean().reset_index()
grouped
# Out:
#    quality    alcohol  volatile acidity   density
# 0        3  10.345000          0.333250  0.994884
# 1        4  10.152454          0.381227  0.994277
# 2        5   9.808840          0.302011  0.995263
# 3        6  10.575372          0.260564  0.993961
# 4        7  11.367936          0.262767  0.992452
# 5        8  11.636000          0.277400  0.992236
# 6        9  12.180000          0.298000  0.991460

# %%
melted = grouped.melt(id_vars='quality', var_name='Feature', value_name='Average')
melted
# Out:
#     quality           Feature    Average
# 0         3           alcohol  10.345000
# 1         4           alcohol  10.152454
# 2         5           alcohol   9.808840
# 3         6           alcohol  10.575372
# 4         7           alcohol  11.367936
# 5         8           alcohol  11.636000
# 6         9           alcohol  12.180000
# 7         3  volatile acidity   0.333250
# 8         4  volatile acidity   0.381227
# 9         5  volatile acidity   0.302011
# 10        6  volatile acidity   0.260564
# 11        7  volatile acidity   0.262767
# 12        8  volatile acidity   0.277400
# 13        9  volatile acidity   0.298000
# 14        3           density   0.994884
# 15        4           density   0.994277
# 16        5           density   0.995263
# 17        6           density   0.993961
# 18        7           density   0.992452
# 19        8           density   0.992236
# 20        9           density   0.991460

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='quality', y='Average', hue='Feature', data=melted)
plt.title("Average Feature Values by Wine Quality")
plt.xlabel("Quality Score")
plt.ylabel("Average Value")
plt.legend(title="Feature")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[158], line 4
#       2 sns.barplot(x='quality', y='Average', hue='Feature', data=melted)
#       3 plt.title("Average Feature Values by Wine Quality")
# ----> 4 plt.xlabel("Quality Score")
#       5 plt.ylabel("Average Value")
#       6 plt.legend(title="Feature")
#
# TypeError: 'str' object is not callable

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
features_2 = ['fixed acidity', 'citric acid', 'residual sugar' ]

# %%
grouped_1= df.groupby('quality')[features_2].mean().reset_index()
grouped_1
# Out:
#    quality  fixed acidity  citric acid  residual sugar
# 0        3       7.600000     0.336000        6.392500
# 1        4       7.129448     0.304233        4.628221
# 2        5       6.933974     0.337653        7.334969
# 3        6       6.837671     0.338025        6.441606
# 4        7       6.734716     0.325625        5.186477
# 5        8       6.657143     0.326514        5.671429
# 6        9       7.420000     0.386000        4.120000

# %%
melted_1 = grouped_1.melt(id_vars='quality', var_name='Feature_2', value_name='Average')
melted_1
# Out:
#     quality       Feature_2   Average
# 0         3   fixed acidity  7.600000
# 1         4   fixed acidity  7.129448
# 2         5   fixed acidity  6.933974
# 3         6   fixed acidity  6.837671
# 4         7   fixed acidity  6.734716
# 5         8   fixed acidity  6.657143
# 6         9   fixed acidity  7.420000
# 7         3     citric acid  0.336000
# 8         4     citric acid  0.304233
# 9         5     citric acid  0.337653
# 10        6     citric acid  0.338025
# 11        7     citric acid  0.325625
# 12        8     citric acid  0.326514
# 13        9     citric acid  0.386000
# 14        3  residual sugar  6.392500
# 15        4  residual sugar  4.628221
# 16        5  residual sugar  7.334969
# 17        6  residual sugar  6.441606
# 18        7  residual sugar  5.186477
# 19        8  residual sugar  5.671429
# 20        9  residual sugar  4.120000

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='quality', y='Average', hue='Feature_2', data=melted_1)
plt.title("Average Feature Values by Wine Quality")
plt.xlabel("Quality Score")
plt.ylabel("Average Value")
plt.legend(title="Feature")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[188], line 4
#       2 sns.barplot(x='quality', y='Average', hue='Feature_2', data=melted_1)
#       3 plt.title("Average Feature Values by Wine Quality")
# ----> 4 plt.xlabel("Quality Score")
#       5 plt.ylabel("Average Value")
#       6 plt.legend(title="Feature")
#
# TypeError: 'str' object is not callable

# %%
features_3 = ['chlorides', 'free sulfur dioxide', 'total sulfur dioxide' ]
grouped_2= df.groupby('quality')[features_3].mean().reset_index()
melted_2= grouped_2.melt(id_vars='quality', var_name='Feature_3', value_name='Average')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='quality', y='Average', hue='Feature_3', data=melted_2)
plt.title("Average Feature Values by Wine Quality")
plt.xlabel("Quality Score")
plt.ylabel("Average Value")
plt.legend(title="Feature")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[194], line 4
#       2 sns.barplot(x='quality', y='Average', hue='Feature_3', data=melted_2)
#       3 plt.title("Average Feature Values by Wine Quality")
# ----> 4 plt.xlabel("Quality Score")
#       5 plt.ylabel("Average Value")
#       6 plt.legend(title="Feature")
#
# TypeError: 'str' object is not callable

# %%
features_4 = ['pH', 'sulphates' ]
grouped_3= df.groupby('quality')[features_4].mean().reset_index()
melted_3= grouped_3.melt(id_vars='quality', var_name='Feature_4', value_name='Average')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='quality', y='Average', hue='Feature_4', data=melted_3)
plt.title("Average Feature Values by Wine Quality")
plt.xlabel("Quality Score")
plt.ylabel("Average Value")
plt.legend(title="Feature")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[198], line 4
#       2 sns.barplot(x='quality', y='Average', hue='Feature_4', data=melted_3)
#       3 plt.title("Average Feature Values by Wine Quality")
# ----> 4 plt.xlabel("Quality Score")
#       5 plt.ylabel("Average Value")
#       6 plt.legend(title="Feature")
#
# TypeError: 'str' object is not callable
